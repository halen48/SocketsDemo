# %% [markdown]
# <a href="https://colab.research.google.com/github/halen48/SocketsDemo/blob/main/Copy_of_Cliente_Servidor_(Single_Cell).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket
from multiprocessing import Process
from threading import Thread, Lock
import time
import random
import pickle

# %%
velocidade = 1.5 #@param {type:"slider", min:0.1, max:2, step:0.1}

# %% [markdown]
# <a href="https://docs.python.org/dev/library/socket.html#socket.socket.listen"> Documentação de Socket</a>

# %%
class Server():
  def __init__(self, end, cod, max_clients, tamanho_buffer):
    self.endereco = end
    self.codificacao = cod
    self.max_clients = max_clients
    self.lista_clientes = {}
    self.mutex = Lock()
    self.tamanho_buffer = tamanho_buffer
    self.ultimo_id = 0
    self.clientes_conectados = []

  def adicionar_cliente(self, conn, addr):

    id = self.ultimo_id
    self.ultimo_id += 1
    thread = Thread(target = self.parse_cliente, args=(conn, addr, id))
    self.lista_clientes[id] = ( (conn, thread) )
    self.lista_clientes[id][1].start()

    print("[Servidor] %d/%d clientes conectados"%(len(self.lista_clientes), self.max_clients))

    return id
  
  def checar_conexoes_clientes(self):
    while True:
      #limpa os clientes que estão desconectados
      self.clientes_conectados = list(self.lista_clientes.keys())
      for c_id in self.clientes_conectados:
        if (not self.lista_clientes[c_id][1].is_alive()):
          self.remover_cliente(c_id)
      #Caso a lista tenha espaço para mais clientes, a rotina encerra por aqui
      if (len(self.lista_clientes) < self.max_clients):
          return
      #Se tem mais clientes que o servidor pode suportar, aguarda...
      print("[Servidor] Muitos clientes conectados. Aguardando...")
      print("[Servidor - Debug] IDs Conectados: ", self.clientes_conectados)
      time.sleep(0.5/velocidade)

  def gerenciador_clientes(self):
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
      while True:
        try:
          s.bind(self.endereco)
          s.listen(self.max_clients)
          time.sleep(0.5/velocidade)
          break
        except Exception as e:
          print(e)
          print("Tentando vincular conexão...")
          continue
      
      while True:
        
        self.checar_conexoes_clientes()  

        conn, addr = s.accept()
        print('[Servidor] Foi conectado um cliente em:', addr)
        self.adicionar_cliente(conn, addr)
      #s.close()
  
  def remover_cliente(self,index):
    print('[Servidor] Desconectando o cliente[%d]: %s'%(index,self.lista_clientes[index][0]))
    self.lista_clientes[index][0].close()
    del self.lista_clientes[index]
    print("[Servidor] %d/%d clientes conectados"%(len(self.lista_clientes), self.max_clients))
    

  def parse_cliente(self,conn, addr, id):
    while True:
      try:

        data = conn.recv(self.tamanho_buffer)
        print('\033[3%dm'%(1+id%5)+'[Servidor] recebi', repr(data), 'do cliente <id: %d>'%id,'\x1b[0m')
        if not data:
            break
        
        data = data.decode(self.codificacao)

        valor = random.randint(0,50)

        if(data == 'negativo'):
          valor *= -1
        
        data = pickle.dumps( (id,valor) )
        time.sleep(0.5/velocidade)
        conn.sendall(data)
      except Exception as e:
        print("[Servidor]", e)
        continue
    
  
  def run(self):
    self.gerenciador_clientes()

# %%
class Client():
  def __init__(self, end, cod, tamanho_buffer):
    self.endereco = end
    self.codificacao = cod
    self.tamanho_buffer = tamanho_buffer
    self.id = None

  def connect(self, s):
    while True:
      try:
        s.connect(self.endereco)
        break
      except ConnectionRefusedError:
        #print('[Cliente] Tentando conectar...')
        time.sleep(2)
      except TimeoutError:
        if(self.id):
          print('\033[3%dm'%(1+self.id%5)+'[Cliente] Timeout! <id:%d>'%self.id,'\x1b[0m')
        else:
          print("[Cliente] Timeout! <id: Não conectado>")

  def rotina(self):
  
    with socket.socket(socket.AF_INET, socket.SOCK_STREAM) as s:
      self.connect(s)
      while True:
        time.sleep(1/velocidade)
        mensagem = random.choice(['positivo','negativo'])
        s.sendall(bytes(mensagem,self.codificacao))
        data = pickle.loads ( s.recv(self.tamanho_buffer) )

        if( not self.id):
          self.id = data[0]
        
        print('\033[3%dm'%(1+self.id%5)+'[Cliente] recebi', data[1], 'do servidor <id:%d>'%self.id,'\x1b[0m')
        if(random.randint(0,5) == 0):
          print('\033[3%dm'%(1+self.id%5)+'[Cliente] vou desligar... <id:%d>'%self.id,'\x1b[0m')
          break
        #s.close()
  
  def run(self):
    self.rotina()

# %%
endereco = ('127.0.0.1', 33333)
codificacao = 'latin-1'
tamanho_buffer = 2048

s = Server(endereco,codificacao, 5, tamanho_buffer)

p = Process(target=s.run)
p.start()

while True:
  time.sleep(random.randint(1,3)/5/velocidade)
  Thread(target = Client(endereco,codificacao, tamanho_buffer).run ).start()
  
  
p.join()
# Out:
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35546)
# [Servidor] 1/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35552)
# [Servidor] 2/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35560)
# [Servidor] 3/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35574)
# [Servidor] 4/5 clientes conectados
# [Servidor] recebi b'positivo' do cliente <id: 0>
# [Servidor] recebi b'negativo' do cliente <id: 1>
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35584)
# [Servidor] recebi b'negativo' do cliente <id: 2>
# [Servidor] 5/5 clientes conectados
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [0, 1, 2, 3, 4]
# [Servidor] recebi b'' do cliente <id: 0>
# [Servidor] recebi b'' do cliente <id: 1>
# [Servidor] recebi b'positivo' do cliente <id: 3>
# [Cliente] recebi 3 do servidor <id:0>
# [Cliente] vou desligar... <id:0>
# [Cliente] recebi -36 do servidor <id:1>
# [Cliente] vou desligar... <id:1>
# [Servidor] Desconectando o cliente[0]: <socket.socket fd=61, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 33333), raddr=('127.0.0.1', 35546)>
# [Servidor] 4/5 clientes conectados
# [Servidor] Desconectando o cliente[1]: <socket.socket fd=62, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 33333), raddr=('127.0.0.1', 35552)>
# [Servidor] 3/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35602)
# [Servidor] 4/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35618)
# [Servidor] 5/5 clientes conectados
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 4, 5, 6]
# [Cliente] recebi -23 do servidor <id:2>
# [Servidor] recebi b'negativo' do cliente <id: 4>
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 4, 5, 6]
# [Cliente] recebi 37 do servidor <id:3>
# [Servidor] recebi b'positivo' do cliente <id: 5>
# [Servidor] recebi b'' do cliente <id: 4>
# [Servidor] recebi b'negativo' do cliente <id: 2>
# [Servidor] recebi b'negativo' do cliente <id: 6>
# [Servidor] Desconectando o cliente[4]: <socket.socket fd=65, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 33333), raddr=('127.0.0.1', 35584)>
# [Servidor] 4/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35630)
# [Servidor] 5/5 clientes conectados
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 5, 6, 7]
# [Servidor] recebi b'negativo' do cliente <id: 7>
# [Cliente] recebi -23 do servidor <id:4>
# [Cliente] vou desligar... <id:4>
# [Servidor] recebi b'negativo' do cliente <id: 3>
# [Servidor] recebi b'' do cliente <id: 5>
# [Servidor] Desconectando o cliente[5]: <socket.socket fd=61, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 33333), raddr=('127.0.0.1', 35602)>
# [Servidor] 4/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35640)
# [Servidor] 5/5 clientes conectados
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 6, 7, 8]
# [Cliente] recebi 5 do servidor <id:5>
# [Cliente] vou desligar... <id:5>
# [Cliente] recebi -21 do servidor <id:2>
# [Cliente] recebi -39 do servidor <id:6>
# [Servidor] recebi b'' do cliente <id: 7>
# [Servidor] recebi b'positivo' do cliente <id: 8>
# [Cliente] recebi -38 do servidor <id:7>
# [Cliente] vou desligar... <id:7>
# [Cliente] recebi -19 do servidor <id:3>
# [Servidor] Desconectando o cliente[7]: <socket.socket fd=65, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 33333), raddr=('127.0.0.1', 35630)>
# [Servidor] 4/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35672)
# [Servidor] 5/5 clientes conectados
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 6, 8, 9]
# [Servidor] recebi b'positivo' do cliente <id: 9>
# [Servidor] recebi b'positivo' do cliente <id: 2>
# [Servidor] recebi b'positivo' do cliente <id: 6>
# [Cliente] recebi 49 do servidor <id:8>
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 6, 8, 9]
# [Servidor] recebi b'negativo' do cliente <id: 3>
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 6, 8, 9]
# [Cliente] recebi 3 do servidor <id:9>
# [Cliente] recebi 36 do servidor <id:2>
# [Cliente] recebi 42 do servidor <id:6>
# [Servidor] recebi b'positivo' do cliente <id: 8>
# [Cliente] recebi -5 do servidor <id:3>
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 6, 8, 9]
# [Servidor] recebi b'negativo' do cliente <id: 9>
# [Servidor] recebi b'positivo' do cliente <id: 2>
# [Servidor] recebi b'positivo' do cliente <id: 6>
# [Cliente] recebi 24 do servidor <id:8>
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 6, 8, 9]
# [Servidor] recebi b'positivo' do cliente <id: 3>
# [Servidor] recebi b'' do cliente <id: 6>
# [Servidor] Desconectando o cliente[6]: <socket.socket fd=62, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 33333), raddr=('127.0.0.1', 35618)>
# [Servidor] 4/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35690)
# [Servidor] 5/5 clientes conectados
# [Servidor] recebi b'positivo' do cliente <id: 10>
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 3, 8, 9, 10]
# [Cliente] recebi -19 do servidor <id:9>
# [Cliente] recebi 47 do servidor <id:2>
# [Cliente] recebi 25 do servidor <id:6>
# [Cliente] vou desligar... <id:6>
# [Servidor] recebi b'negativo' do cliente <id: 8>
# [Servidor] recebi b'' do cliente <id: 3>
# [Cliente] recebi 0 do servidor <id:3>
# [Cliente] vou desligar... <id:3>
# [Servidor] Desconectando o cliente[3]: <socket.socket fd=64, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 33333), raddr=('127.0.0.1', 35574)>
# [Servidor] 4/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35704)
# [Servidor] recebi b'positivo' do cliente <id: 11>
# [Servidor] 5/5 clientes conectados
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 8, 9, 10, 11]
# [Servidor] recebi b'positivo' do cliente <id: 9>
# [Servidor] recebi b'negativo' do cliente <id: 2>
# [Cliente] recebi 28 do servidor <id:10>
# [Cliente] recebi -27 do servidor <id:8>
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 8, 9, 10, 11]
# [Servidor] recebi b'' do cliente <id: 9>
# [Cliente] recebi 5 do servidor <id:11>
# [Cliente] recebi 27 do servidor <id:9>
# [Cliente] vou desligar... <id:9>
# [Cliente] recebi -46 do servidor <id:2>
# [Servidor] recebi b'negativo' do cliente <id: 10>
# [Servidor] Desconectando o cliente[9]: <socket.socket fd=65, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 33333), raddr=('127.0.0.1', 35672)>
# [Servidor] 4/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35714)
# [Servidor] 5/5 clientes conectados
# [Servidor] recebi b'positivo' do cliente <id: 12>
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 8, 10, 11, 12]
# [Servidor] recebi b'positivo' do cliente <id: 8>
# [Servidor] recebi b'positivo' do cliente <id: 11>
# [Servidor] recebi b'' do cliente <id: 12>
# [Servidor] Desconectando o cliente[12]: <socket.socket fd=65, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 33333), raddr=('127.0.0.1', 35714)>
# [Servidor] 4/5 clientes conectados
# [Servidor] Foi conectado um cliente em: ('127.0.0.1', 35724)
# [Servidor] 5/5 clientes conectados
# [Servidor] Muitos clientes conectados. Aguardando...
# [Servidor - Debug] IDs Conectados:  [2, 8, 10, 11, 13]
# [Servidor] recebi b'positivo' do cliente <id: 13>
# [Servidor] recebi b'negativo' do cliente <id: 2>
# [Cliente] recebi -46 do servidor <id:10>
# [Cliente] recebi 40 do servidor <id:12>
# [Cliente] vou desligar... <id:12>
# [Cliente] recebi 16 do servidor <id:8>
# Process Process-1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-3-501932ab7490>", line 93, in run
#     self.gerenciador_clientes()
#   File "<ipython-input-3-501932ab7490>", line 54, in gerenciador_clientes
#     self.checar_conexoes_clientes()
#   File "<ipython-input-3-501932ab7490>", line 37, in checar_conexoes_clientes
#     time.sleep(0.5/velocidade)
# KeyboardInterrupt
# [Servidor] recebi b'' do cliente <id: 2>
# [Cliente] recebi 22 do servidor <id:11>
# [Cliente] recebi 33 do servidor <id:13>
# [Cliente] recebi -12 do servidor <id:2>
# [Cliente] vou desligar... <id:2>
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-2146df43ca44>", line 42, in run
#     self.rotina()
#   File "<ipython-input-4-2146df43ca44>", line 30, in rotina
#     data = pickle.loads ( s.recv(self.tamanho_buffer) )
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-27:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-2146df43ca44>", line 42, in run
#     self.rotina()
#   File "<ipython-input-4-2146df43ca44>", line 30, in rotina
#     data = pickle.loads ( s.recv(self.tamanho_buffer) )
# ConnectionResetError: [Errno 104] Connection reset by peer
#
# Exception in thread Thread-30:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-2146df43ca44>", line 42, in run
#     self.rotina()
#   File "<ipython-input-4-2146df43ca44>", line 30, in rotina
#     data = pickle.loads ( s.recv(self.tamanho_buffer) )
# ConnectionResetError: [Errno 104] Connection reset by peer
# Exception in thread Thread-25:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-2146df43ca44>", line 42, in run
#     self.rotina()
#   File "<ipython-input-4-2146df43ca44>", line 30, in rotina
#     data = pickle.loads ( s.recv(self.tamanho_buffer) )
# ConnectionResetError: [Errno 104] Connection reset by peer
#
#
# Exception in thread Thread-35:
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-4-2146df43ca44>", line 42, in run
#     self.rotina()
#   File "<ipython-input-4-2146df43ca44>", line 29, in rotina
#     s.sendall(bytes(mensagem,self.codificacao))
# ConnectionResetError: [Errno 104] Connection reset by peer
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c038893cb856> in <module>()
#       9
#      10 while True:
# ---> 11   time.sleep(random.randint(1,3)/5/velocidade)
#      12   Thread(target = Client(endereco,codificacao, tamanho_buffer).run ).start()
#      13
#
# KeyboardInterrupt:
# [Servidor] recebi b'negativo' do cliente <id: 10>
# [Servidor] recebi b'negativo' do cliente <id: 8>
